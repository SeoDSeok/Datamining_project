# %%
import pandas as pd

# %%
# data_load
data1 = pd.read_csv('ocean_2011.csv', encoding='cp949')
data2 = pd.read_csv('ocean_2012.csv', encoding='cp949')
data3 = pd.read_csv('ocean_2013.csv', encoding='cp949')
data4 = pd.read_csv('ocean_2014.csv', encoding='cp949')
data5 = pd.read_csv('ocean_2015.csv', encoding='cp949')
data6 = pd.read_csv('ocean_2016.csv', encoding='cp949')
data7 = pd.read_csv('ocean_2017.csv', encoding='cp949')
data8 = pd.read_csv('ocean_2018.csv', encoding='cp949')
data9 = pd.read_csv('ocean_2019.csv', encoding='cp949')
data10 = pd.read_csv('ocean_2020.csv', encoding='cp949')
data11 = pd.read_csv('ocean_2021.csv', encoding='cp949')

# %% [markdown]
# - data9를 기준으로 같은 값을 가지지만 컬럼명이 다른 것이 존재!
# - 최근 데이터를 기준으로 컬럼명 일치 시키기는 작업을 rename으로 시행함
# - 선종2, 톤수2, 선종3, 톤수3을 가진 데이터가 적고 또한, 사고선박수와 일치 하지 않으므로 삭제

# %%
data1.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상특보', '사고선박수', '구조인원',
#        '부상인원', '사망인원', '실종인원', '사고위치', '위도', '경도', '선종1', '톤수1', '선종2', '톤수2',
#        '선종3', '톤수3'],
#       dtype='object')

# %% [markdown]
# ### 구조인원 -> 구조, 부상인원 -> 부상, 사망인원 -> 사망, 실종인원 -> 실종, 톤수1 -> 톤수, 선종1 -> 선 종, 기상특보 -> 기상상태

# %%
data1.rename(columns={'구조인원':'구조','부상인원':'부상','사망인원':'사망','실종인원':'실종','선종1':'선 종','톤수1':'톤수', '기상특보':'기상상태'}, inplace=True)

# %%
data1.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상상태', '사고선박수', '구조', '부상',
#        '사망', '실종', '사고위치', '위도', '경도', '선 종', '톤수', '선종2', '톤수2', '선종3',
#        '톤수3'],
#       dtype='object')

# %%
data1.drop(['선종2', '선종3', '톤수3', '톤수2'], axis = 1, inplace = True)

# %%
data1.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상상태', '사고선박수', '구조', '부상',
#        '사망', '실종', '사고위치', '위도', '경도', '선 종', '톤수'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상특보', '사고선박수', '구조인원',
#        '부상인원', '사망인원', '실종인원', '사고위치', '위도', '경도', '선종1', '톤수1', '선종2', '톤수2',
#        '선종3', '톤수3'],
#       dtype='object')

# %%
data2.rename(columns={'구조인원':'구조','부상인원':'부상','사망인원':'사망','실종인원':'실종','선종1':'선 종','톤수1':'톤수', '기상특보':'기상상태'}, inplace=True)

# %%
data2.drop(['선종2', '선종3', '톤수3', '톤수2'], axis = 1, inplace = True)

# %%
data2.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상상태', '사고선박수', '구조', '부상',
#        '사망', '실종', '사고위치', '위도', '경도', '선 종', '톤수'],
#       dtype='object')

# %%
data3.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상특보', '사고선박수', '구조인원',
#        '부상인원', '사망인원', '실종인원', '사고위치', '위도', '경도', '선종1', '톤수1', '선종2', '톤수2',
#        '선종3', '톤수3'],
#       dtype='object')

# %%
data3.rename(columns={'구조인원':'구조','부상인원':'부상','사망인원':'사망','실종인원':'실종','선종1':'선 종','톤수1':'톤수', '기상특보':'기상상태'}, inplace=True)

# %%
data3.drop(['선종2', '선종3', '톤수3', '톤수2'], axis = 1, inplace = True)

# %%
data3.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상상태', '사고선박수', '구조', '부상',
#        '사망', '실종', '사고위치', '위도', '경도', '선 종', '톤수'],
#       dtype='object')

# %%
data4.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상특보', '사고선박수', '구조인원',
#        '부상인원', '사망인원', '실종인원', '사고위치', '위도', '경도', '선종1', '톤수1', '선종2', '톤수2',
#        '선종3', '톤수3'],
#       dtype='object')

# %%
data4.rename(columns={'구조인원':'구조','부상인원':'부상','사망인원':'사망','실종인원':'실종','선종1':'선 종','톤수1':'톤수', '기상특보':'기상상태'}, inplace=True)

# %%
data4.drop(['선종2', '선종3', '톤수3', '톤수2'], axis = 1, inplace = True)

# %%
data4.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상상태', '사고선박수', '구조', '부상',
#        '사망', '실종', '사고위치', '위도', '경도', '선 종', '톤수'],
#       dtype='object')

# %%
data5.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상특보', '사고선박수', '구조인원',
#        '부상인원', '사망인원', '실종인원', '사고위치', '위도', '경도', '선종1', '톤수1', '선종2', '톤수2',
#        '선종3', '톤수3'],
#       dtype='object')

# %%
data5.rename(columns={'구조인원':'구조','부상인원':'부상','사망인원':'사망','실종인원':'실종','선종1':'선 종','톤수1':'톤수', '기상특보':'기상상태'}, inplace=True)

# %%
data5.drop(['선종2', '선종3', '톤수3', '톤수2'], axis = 1, inplace = True)

# %%
data5.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상상태', '사고선박수', '구조', '부상',
#        '사망', '실종', '사고위치', '위도', '경도', '선 종', '톤수'],
#       dtype='object')

# %%
data6.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상특보', '사고선박수', '구조인원',
#        '부상인원', '사망인원', '실종인원', '사고위치', '위도', '경도', '선종1', '톤수1', '선종2', '톤수2',
#        '선종3', '톤수3'],
#       dtype='object')

# %%
data6.rename(columns={'구조인원':'구조','부상인원':'부상','사망인원':'사망','실종인원':'실종','선종1':'선 종','톤수1':'톤수', '기상특보':'기상상태'}, inplace=True)

# %%
data6.drop(['선종2', '선종3', '톤수3', '톤수2'], axis = 1, inplace = True)

# %%
data6.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상상태', '사고선박수', '구조', '부상',
#        '사망', '실종', '사고위치', '위도', '경도', '선 종', '톤수'],
#       dtype='object')

# %%
data7.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상특보', '사고선박수', '구조인원',
#        '부상인원', '사망인원', '실종인원', '사고위치', '위도', '경도', '선종1', '톤수1', '선종2', '톤수2',
#        '선종3', '톤수3'],
#       dtype='object')

# %%
data7.rename(columns={'구조인원':'구조','부상인원':'부상','사망인원':'사망','실종인원':'실종','선종1':'선 종','톤수1':'톤수', '기상특보':'기상상태'}, inplace=True)

# %%
data7.drop(['선종2', '선종3', '톤수3', '톤수2'], axis = 1, inplace = True)

# %%
data7.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상상태', '사고선박수', '구조', '부상',
#        '사망', '실종', '사고위치', '위도', '경도', '선 종', '톤수'],
#       dtype='object')

# %%
data8.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상특보', '사고선박수', '구조인원',
#        '부상인원', '사망인원', '실종인원', '사고위치', '위도', '경도', '선종1', '톤수1', '선종2', '톤수2',
#        '선종3', '톤수3'],
#       dtype='object')

# %%
data8.rename(columns={'구조인원':'구조','부상인원':'부상','사망인원':'사망','실종인원':'실종','선종1':'선 종','톤수1':'톤수', '기상특보':'기상상태'}, inplace=True)

# %%
data8.drop(['선종2', '선종3', '톤수3', '톤수2'], axis = 1, inplace = True)

# %%
data8.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상상태', '사고선박수', '구조', '부상',
#        '사망', '실종', '사고위치', '위도', '경도', '선 종', '톤수'],
#       dtype='object')

# %%
data9.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '위도', '경도', '기상상태', '발생원인', '발생유형', '사고선박수',
#        '발생인원', '구조', '부상', '사망', '실종', '선 종', '톤수'],
#       dtype='object')

# %%
data10.columns
# Out:
# Index(['발생일시', '월별', '시간대별', '관할해경서', '발생해역', '위도', '경도', '기상상태', '발생원인',
#        '발생유형', '사고선박수', '발생인원', '구조', '부상', '사망', '실종', '선 종', '톤수'],
#       dtype='object')

# %% [markdown]
# data11에 무의미한 컬럼 삭제

# %%
data11.columns
# Out:
# Index(['발생일시', '월별', '시간대별', '관할해경서', '발생해역', '위도', '경도', '기상상태', '발생원인',
#        '발생유형', '사고선박수', '발생인원', '구조', '부상', '사망', '실종', '선 종', '톤수',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37'],
#       dtype='object')

# %%
data11.dropna(axis=1, inplace=True, how='all')

# %%
data11.columns
# Out:
# Index(['발생일시', '월별', '시간대별', '관할해경서', '발생해역', '위도', '경도', '기상상태', '발생원인',
#        '발생유형', '사고선박수', '발생인원', '구조', '부상', '사망', '실종', '선 종', '톤수'],
#       dtype='object')

# %% [markdown]
# - data10, data11에만 월별과 시간대별 칼럼이 존재
# - 이를 처리하여 주기 위해 발생일시에서 월과 시간을 추출하여 나머지 data의 컬럼 생성

# %%
month = []
count = 0
for str in data9['발생일시']:
    month.append(str[5:7])
    count += 1

# %%
data9['월별'] = month

# %%
data9
# Out:
#                   발생일시 관할해경서    발생해역            위도             경도 기상상태   발생원인  \
# 0     2019-12-31 22:04    포항      영해     0 | 0 | 0      0 | 0 | 0   양호   관리소홀
# 1     2019-12-31 15:13    포항      영해   35 | 52 | 3  129 | 45 | 55   양호  운항부주의
# 2     2019-12-31 15:13    포항      영해   35 | 52 | 3  129 | 45 | 55   양호  운항부주의
# 3     2019-12-31 09:33    통영     협수로   34 | 41 | 6   128 | 3 | 59   양호  운항부주의
# 4     2019-12-31 08:38    군산    항계 내  35 | 59 | 18  126 | 41 | 43   양호   관리소홀
# ...                ...   ...     ...           ...            ...  ...    ...
# 3815  2019-01-01 14:08    인천      영해  37 | 21 | 28  126 | 25 | 49   양호  운항부주의
# 3816  2019-01-01 09:14    인천     협수로   37 | 13 | 0    126 | 9 | 0   양호  운항부주의
# 3817  2019-01-01 07:59    완도    항계 내  34 | 28 | 52  126 | 56 | 41   양호  운항부주의
# 3818  2019-01-01 03:31    태안      영해  36 | 46 | 60    126 | 1 | 0   양호  운항부주의
# 3819  2019-01-01 00:10   서귀포  영해-EEZ  32 | 49 | 60    127 | 3 | 0   양호   정비불량
#
# ...

# %%
time = []
for str in data9['발생일시']:
    time.append(str[11:13])
    
len(time)
# Out:
# 3820

# %%
data9['시간대별'] = time

# %%
data9
# Out:
#                   발생일시 관할해경서    발생해역            위도             경도 기상상태   발생원인  \
# 0     2019-12-31 22:04    포항      영해     0 | 0 | 0      0 | 0 | 0   양호   관리소홀
# 1     2019-12-31 15:13    포항      영해   35 | 52 | 3  129 | 45 | 55   양호  운항부주의
# 2     2019-12-31 15:13    포항      영해   35 | 52 | 3  129 | 45 | 55   양호  운항부주의
# 3     2019-12-31 09:33    통영     협수로   34 | 41 | 6   128 | 3 | 59   양호  운항부주의
# 4     2019-12-31 08:38    군산    항계 내  35 | 59 | 18  126 | 41 | 43   양호   관리소홀
# ...                ...   ...     ...           ...            ...  ...    ...
# 3815  2019-01-01 14:08    인천      영해  37 | 21 | 28  126 | 25 | 49   양호  운항부주의
# 3816  2019-01-01 09:14    인천     협수로   37 | 13 | 0    126 | 9 | 0   양호  운항부주의
# 3817  2019-01-01 07:59    완도    항계 내  34 | 28 | 52  126 | 56 | 41   양호  운항부주의
# 3818  2019-01-01 03:31    태안      영해  36 | 46 | 60    126 | 1 | 0   양호  운항부주의
# 3819  2019-01-01 00:10   서귀포  영해-EEZ  32 | 49 | 60    127 | 3 | 0   양호   정비불량
#
# ...

# %% [markdown]
# ### 공통된 칼럼을 가지므로 data 합치기

# %%
df = pd.concat([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11], ignore_index=True)

# %%
df
# Out:
#                    발생일시 관할해경서    발생해역   발생유형   발생원인 기상상태  사고선박수    구조   부상  \
# 0      2011-12-31 13:20    울산  영해-EEZ     화재   관리소홀   양호    1.0   4.0  0.0
# 1      2011-12-31 12:22    통영     항계내  추진기장애  운항부주의   양호    1.0   2.0  0.0
# 2      2011-12-31 06:40    여수      영해     전복  운항부주의   양호    1.0   5.0  0.0
# 3      2011-12-30 21:15    부산     항계내     화재   정비불량   양호    1.0  67.0  0.0
# 4      2011-12-30 12:00   서귀포  영해-EEZ   기관고장   정비불량   양호    1.0   6.0  0.0
# ...                 ...   ...     ...    ...    ...  ...    ...   ...  ...
# 27864  2021-01-01 15:31    울산      영해   기관손상   정비불량   양호    1.0   1.0  0.0
# 27865  2021-01-01 12:02    창원      영해   기관손상   정비불량   양호    1.0  15.0  0.0
# 27866  2021-01-01 12:01    통영     협수로   기관손상   정비불량   양호    1.0  15.0  0.0
# 27867  2021-01-01 11:45    여수      영해     충돌  운항부주의   양호    1.0  12.0  0.0
# 27868  2021-01-01 11:45    여수      영해     충돌  운항부주의   양호    1.0  57.0  0.0
#
# ...

# %%
data9.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '위도', '경도', '기상상태', '발생원인', '발생유형', '사고선박수',
#        '발생인원', '구조', '부상', '사망', '실종', '선 종', '톤수', '월별', '시간대별'],
#       dtype='object')

# %%
data8.columns
# Out:
# Index(['발생일시', '관할해경서', '발생해역', '발생유형', '발생원인', '기상상태', '사고선박수', '구조', '부상',
#        '사망', '실종', '사고위치', '위도', '경도', '선 종', '톤수', '월별', '시간대별'],
#       dtype='object')

# %%
data11.columns
# Out:
# Index(['발생일시', '월별', '시간대별', '관할해경서', '발생해역', '위도', '경도', '기상상태', '발생원인',
#        '발생유형', '사고선박수', '발생인원', '구조', '부상', '사망', '실종', '선 종', '톤수'],
#       dtype='object')

# %% [markdown]
# ## 사고위치 칼럼은 최근 데이터에는 존재 하지 않고 이는 관할해경서 및 발생해역으로 대체가능하다고 판단하여 예전데이터에 사고위치 칼럼 삭제

# %%
data1.drop(['사고위치'], axis = 1, inplace = True)
data2.drop(['사고위치'], axis = 1, inplace = True)
data3.drop(['사고위치'], axis = 1, inplace = True)
data4.drop(['사고위치'], axis = 1, inplace = True)
data5.drop(['사고위치'], axis = 1, inplace = True)
data6.drop(['사고위치'], axis = 1, inplace = True)
data7.drop(['사고위치'], axis = 1, inplace = True)
data8.drop(['사고위치'], axis = 1, inplace = True)

# %%
data1['발생인원'] = data1['구조'] + data1['부상'] + data1['사망'] + data1['실종']
data2['발생인원'] = data2['구조'] + data2['부상'] + data2['사망'] + data2['실종']
data3['발생인원'] = data3['구조'] + data3['부상'] + data3['사망'] + data3['실종']
data4['발생인원'] = data4['구조'] + data4['부상'] + data4['사망'] + data4['실종']
data5['발생인원'] = data5['구조'] + data5['부상'] + data5['사망'] + data5['실종']
data6['발생인원'] = data6['구조'] + data6['부상'] + data6['사망'] + data6['실종']
data7['발생인원'] = data7['구조'] + data7['부상'] + data7['사망'] + data7['실종']
data8['발생인원'] = data8['구조'] + data8['부상'] + data8['사망'] + data8['실종']

# %%
df = pd.concat([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11], ignore_index=True)

# %%
df
# Out:
#                    발생일시 관할해경서    발생해역   발생유형   발생원인 기상상태  사고선박수    구조   부상  \
# 0      2011-12-31 13:20    울산  영해-EEZ     화재   관리소홀   양호    1.0   4.0  0.0
# 1      2011-12-31 12:22    통영     항계내  추진기장애  운항부주의   양호    1.0   2.0  0.0
# 2      2011-12-31 06:40    여수      영해     전복  운항부주의   양호    1.0   5.0  0.0
# 3      2011-12-30 21:15    부산     항계내     화재   정비불량   양호    1.0  67.0  0.0
# 4      2011-12-30 12:00   서귀포  영해-EEZ   기관고장   정비불량   양호    1.0   6.0  0.0
# ...                 ...   ...     ...    ...    ...  ...    ...   ...  ...
# 27864  2021-01-01 15:31    울산      영해   기관손상   정비불량   양호    1.0   1.0  0.0
# 27865  2021-01-01 12:02    창원      영해   기관손상   정비불량   양호    1.0  15.0  0.0
# 27866  2021-01-01 12:01    통영     협수로   기관손상   정비불량   양호    1.0  15.0  0.0
# 27867  2021-01-01 11:45    여수      영해     충돌  운항부주의   양호    1.0  12.0  0.0
# 27868  2021-01-01 11:45    여수      영해     충돌  운항부주의   양호    1.0  57.0  0.0
#
# ...

# %% [markdown]
# 위도와 경도는 세분화된 분과 초단위까지 사용하지 않을 것이므로 앞에 있는 도만 차용

# %%
df['위도'] = df['위도'].apply(lambda x: x[0:2])
df
# Out:
#                    발생일시 관할해경서    발생해역   발생유형   발생원인 기상상태  사고선박수    구조   부상  \
# 0      2011-12-31 13:20    울산  영해-EEZ     화재   관리소홀   양호    1.0   4.0  0.0
# 1      2011-12-31 12:22    통영     항계내  추진기장애  운항부주의   양호    1.0   2.0  0.0
# 2      2011-12-31 06:40    여수      영해     전복  운항부주의   양호    1.0   5.0  0.0
# 3      2011-12-30 21:15    부산     항계내     화재   정비불량   양호    1.0  67.0  0.0
# 4      2011-12-30 12:00   서귀포  영해-EEZ   기관고장   정비불량   양호    1.0   6.0  0.0
# ...                 ...   ...     ...    ...    ...  ...    ...   ...  ...
# 27864  2021-01-01 15:31    울산      영해   기관손상   정비불량   양호    1.0   1.0  0.0
# 27865  2021-01-01 12:02    창원      영해   기관손상   정비불량   양호    1.0  15.0  0.0
# 27866  2021-01-01 12:01    통영     협수로   기관손상   정비불량   양호    1.0  15.0  0.0
# 27867  2021-01-01 11:45    여수      영해     충돌  운항부주의   양호    1.0  12.0  0.0
# 27868  2021-01-01 11:45    여수      영해     충돌  운항부주의   양호    1.0  57.0  0.0
#
#         사망   실종  위도             경도   선 종       톤수  월별 시간대별  발생인원
# ...

# %%
df['경도'] = df['경도'].apply(lambda x: x[0:2])
df
# Out:
#                    발생일시 관할해경서    발생해역   발생유형   발생원인 기상상태  사고선박수    구조   부상  \
# 0      2011-12-31 13:20    울산  영해-EEZ     화재   관리소홀   양호    1.0   4.0  0.0
# 1      2011-12-31 12:22    통영     항계내  추진기장애  운항부주의   양호    1.0   2.0  0.0
# 2      2011-12-31 06:40    여수      영해     전복  운항부주의   양호    1.0   5.0  0.0
# 3      2011-12-30 21:15    부산     항계내     화재   정비불량   양호    1.0  67.0  0.0
# 4      2011-12-30 12:00   서귀포  영해-EEZ   기관고장   정비불량   양호    1.0   6.0  0.0
# ...                 ...   ...     ...    ...    ...  ...    ...   ...  ...
# 27864  2021-01-01 15:31    울산      영해   기관손상   정비불량   양호    1.0   1.0  0.0
# 27865  2021-01-01 12:02    창원      영해   기관손상   정비불량   양호    1.0  15.0  0.0
# 27866  2021-01-01 12:01    통영     협수로   기관손상   정비불량   양호    1.0  15.0  0.0
# 27867  2021-01-01 11:45    여수      영해     충돌  운항부주의   양호    1.0  12.0  0.0
# 27868  2021-01-01 11:45    여수      영해     충돌  운항부주의   양호    1.0  57.0  0.0
#
#         사망   실종  위도  경도   선 종       톤수  월별 시간대별  발생인원
# ...

# %% [markdown]
# ## 발생해역에서 외국해역 및 EEZ-30망일 이내 북한해역은 목적에 부합하지 않다고 판단하여 삭제

# %%
df['발생해역'].value_counts()
# Out:
# 영해             15201
# 항계내             4254
# 항계 내            3776
# 영해-EEZ          2380
# 협수로             1726
# 공해               300
# EEZ 30마일 이내      154
# 외국해역              63
# EEZ-30마일 이내       14
# 북한해역               1
# Name: 발생해역, dtype: int64

# %%
df = df[df.발생해역 != '외국해역']
df = df[df.발생해역 != 'EEZ-30마일 이내']
df = df[df.발생해역 != '북한해역']

# %%
df
# Out:
#                    발생일시 관할해경서    발생해역   발생유형   발생원인 기상상태  사고선박수    구조   부상  \
# 0      2011-12-31 13:20    울산  영해-EEZ     화재   관리소홀   양호    1.0   4.0  0.0
# 1      2011-12-31 12:22    통영     항계내  추진기장애  운항부주의   양호    1.0   2.0  0.0
# 2      2011-12-31 06:40    여수      영해     전복  운항부주의   양호    1.0   5.0  0.0
# 3      2011-12-30 21:15    부산     항계내     화재   정비불량   양호    1.0  67.0  0.0
# 4      2011-12-30 12:00   서귀포  영해-EEZ   기관고장   정비불량   양호    1.0   6.0  0.0
# ...                 ...   ...     ...    ...    ...  ...    ...   ...  ...
# 27864  2021-01-01 15:31    울산      영해   기관손상   정비불량   양호    1.0   1.0  0.0
# 27865  2021-01-01 12:02    창원      영해   기관손상   정비불량   양호    1.0  15.0  0.0
# 27866  2021-01-01 12:01    통영     협수로   기관손상   정비불량   양호    1.0  15.0  0.0
# 27867  2021-01-01 11:45    여수      영해     충돌  운항부주의   양호    1.0  12.0  0.0
# 27868  2021-01-01 11:45    여수      영해     충돌  운항부주의   양호    1.0  57.0  0.0
#
#         사망   실종  위도  경도   선 종       톤수  월별 시간대별  발생인원
# ...

# %% [markdown]
# ### 사고선박수는 거의 1이고 위에서 언급했듯이 선종2, 선종3는 삭제하였으므로 의미없는 칼럼이라 판단하여 삭제

# %%
df.drop(['사고선박수'], axis = 1, inplace = True)
df
# Out:
#                    발생일시 관할해경서    발생해역   발생유형   발생원인 기상상태    구조   부상   사망   실종  \
# 0      2011-12-31 13:20    울산  영해-EEZ     화재   관리소홀   양호   4.0  0.0  0.0  0.0
# 1      2011-12-31 12:22    통영     항계내  추진기장애  운항부주의   양호   2.0  0.0  0.0  0.0
# 2      2011-12-31 06:40    여수      영해     전복  운항부주의   양호   5.0  0.0  0.0  0.0
# 3      2011-12-30 21:15    부산     항계내     화재   정비불량   양호  67.0  0.0  0.0  0.0
# 4      2011-12-30 12:00   서귀포  영해-EEZ   기관고장   정비불량   양호   6.0  0.0  0.0  0.0
# ...                 ...   ...     ...    ...    ...  ...   ...  ...  ...  ...
# 27864  2021-01-01 15:31    울산      영해   기관손상   정비불량   양호   1.0  0.0  0.0  0.0
# 27865  2021-01-01 12:02    창원      영해   기관손상   정비불량   양호  15.0  0.0  0.0  0.0
# 27866  2021-01-01 12:01    통영     협수로   기관손상   정비불량   양호  15.0  0.0  0.0  0.0
# 27867  2021-01-01 11:45    여수      영해     충돌  운항부주의   양호  12.0  0.0  0.0  0.0
# 27868  2021-01-01 11:45    여수      영해     충돌  운항부주의   양호  57.0  0.0  0.0  0.0
#
# ...

# %% [markdown]
# ## 단순한 feature extraction 사고규모라는 지표를 톤수당 발생이원으로 추론해보고자 함

# %%
df['사고규모'] = df['발생인원']/df['톤수']
df
# Out:
#                    발생일시 관할해경서    발생해역   발생유형   발생원인 기상상태    구조   부상   사망   실종  \
# 0      2011-12-31 13:20    울산  영해-EEZ     화재   관리소홀   양호   4.0  0.0  0.0  0.0
# 1      2011-12-31 12:22    통영     항계내  추진기장애  운항부주의   양호   2.0  0.0  0.0  0.0
# 2      2011-12-31 06:40    여수      영해     전복  운항부주의   양호   5.0  0.0  0.0  0.0
# 3      2011-12-30 21:15    부산     항계내     화재   정비불량   양호  67.0  0.0  0.0  0.0
# 4      2011-12-30 12:00   서귀포  영해-EEZ   기관고장   정비불량   양호   6.0  0.0  0.0  0.0
# ...                 ...   ...     ...    ...    ...  ...   ...  ...  ...  ...
# 27864  2021-01-01 15:31    울산      영해   기관손상   정비불량   양호   1.0  0.0  0.0  0.0
# 27865  2021-01-01 12:02    창원      영해   기관손상   정비불량   양호  15.0  0.0  0.0  0.0
# 27866  2021-01-01 12:01    통영     협수로   기관손상   정비불량   양호  15.0  0.0  0.0  0.0
# 27867  2021-01-01 11:45    여수      영해     충돌  운항부주의   양호  12.0  0.0  0.0  0.0
# 27868  2021-01-01 11:45    여수      영해     충돌  운항부주의   양호  57.0  0.0  0.0  0.0
#
# ...

# %%
df.to_csv('./well_processing.csv',index=False, encoding='utf-8-sig')
