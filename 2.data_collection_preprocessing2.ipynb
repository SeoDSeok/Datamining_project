# %%
#라이브러리 import
import csv
import pandas as pd

# %%
#csv파일(날씨정보) 불러오기
csv_file_path = "/Users/82107/Downloads/OBS_BUOY_TIM_2020_2021.csv"
csv_file_path1 = "/Users/82107/Downloads/OBS_BUOY_TIM_2011_2019.csv"

# %%
#csv파일 데이터 확인
with open(csv_file_path, "r") as csv_file:
    csv_reader = csv.reader(csv_file)
    
    for i in csv_reader:
        print(i)
# Out:
# ['지점', '일시', '풍속(m/s)', '풍향(deg)', 'GUST풍속(m/s)', '현지기압(hPa)', '습도(%)', '기온(°C)', '수온(°C)', '최대파고(m)', '유의파고(m)', '평균파고(m)', '파주기(sec)', '파향(deg)']
# ['21229', '2020-01-01 0:00', '6.6', '273', '10.5', '1026.4', '51', '3.7', '13.7', '3.4', '2.2', '1.6', '9.1', '42']
# ['21229', '2020-01-01 2:00', '7.5', '275', '10.6', '1025.5', '53', '3.8', '13.6', '3.2', '2', '1.4', '9.1', '50']
# ['21229', '2020-01-01 3:00', '7.5', '284', '10.6', '1025.5', '56', '4.1', '13.5', '3.4', '2.1', '1.5', '8', '48']
# ['21229', '2020-01-01 4:00', '4.9', '315', '7.4', '1025.2', '50', '3.5', '13.5', '3.2', '1.9', '1.3', '8', '40']
# ['21229', '2020-01-01 5:00', '5.8', '297', '8.7', '1024.7', '54', '3.6', '13.6', '2.8', '1.8', '1.3', '8', '31']
# ['21229', '2020-01-01 6:00', '6.7', '305', '10.4', '1024.8', '55', '4.3', '13.7', '3.5', '1.7', '1.2', '7.1', '21']
# ['21229', '2020-01-01 7:00', '7.1', '286', '11', '1025.2', '53', '4.3', '13.7', '3.3', '1.9', '1.4', '8', '28']
# ...

# %%
#csv 파일 dataframe으로 만들기
df = pd.read_csv(csv_file_path, encoding="euc-kr")
df1 = pd.read_csv(csv_file_path1, encoding="euc-kr")

# %%
df
# Out:
#              지점                일시  풍속(m/s)  풍향(deg)  GUST풍속(m/s)  현지기압(hPa)  \
# 0       21229.0   2020-01-01 0:00      6.6    273.0         10.5     1026.4
# 1       21229.0   2020-01-01 2:00      7.5    275.0         10.6     1025.5
# 2       21229.0   2020-01-01 3:00      7.5    284.0         10.6     1025.5
# 3       21229.0   2020-01-01 4:00      4.9    315.0          7.4     1025.2
# 4       21229.0   2020-01-01 5:00      5.8    297.0          8.7     1024.7
# ...         ...               ...      ...      ...          ...        ...
# 380692  22302.0  2021-12-31 19:00     10.9    336.0         15.1     1024.9
# 380693  22302.0  2021-12-31 20:00      8.9    334.0         12.2     1025.5
# 380694  22302.0  2021-12-31 21:00      8.8    320.0         14.1     1025.7
# 380695  22302.0  2021-12-31 22:00      8.2    315.0         10.7     1026.2
# 380696  22302.0  2021-12-31 23:00      8.0    307.0         10.8     1026.2
#
# ...

# %%
#df의 지점 고유번호를 지점명으로 변경

df.loc[df["지점"]==22297,"지점"] = "가거도"
df.loc[df["지점"]==22193,"지점"] = "가거도"
df.loc[df["지점"]==22103,"지점"] = "거문도"
df.loc[df["지점"]==22104,"지점"] = "거제도"
df.loc[df["지점"]==22300,"지점"] = "남해239"
df.loc[df["지점"]==22301,"지점"] = "남해465"
df.loc[df["지점"]==22101,"지점"] = "덕적도"
df.loc[df["지점"]==22105,"지점"] = "동해 "
df.loc[df["지점"]==22302,"지점"] = "동해78 "
df.loc[df["지점"]==22107,"지점"] = "마라도 "
df.loc[df["지점"]==22186,"지점"] = "부안 "
df.loc[df["지점"]==22187,"지점"] = "서귀포"
df.loc[df["지점"]==22191,"지점"] = "서해170"
df.loc[df["지점"]==22299,"지점"] = "서해190"
df.loc[df["지점"]==22192,"지점"] = "서해206"
df.loc[df["지점"]==22183,"지점"] = "신안"
df.loc[df["지점"]==22108,"지점"] = "외연도"
df.loc[df["지점"]==21229,"지점"] = "울릉도"
df.loc[df["지점"]==22189,"지점"] = "울산"
df.loc[df["지점"]==22190,"지점"] = "울진"
df.loc[df["지점"]==22185,"지점"] = "인천"
df.loc[df["지점"]==22184,"지점"] = "추자도"
df.loc[df["지점"]==22102,"지점"] = "칠발도"
df.loc[df["지점"]==22188,"지점"] = "통영"
df.loc[df["지점"]==22106,"지점"] = "포항"
df.loc[df["지점"]==22303,"지점"] = "풍도"
df.loc[df["지점"]==22298,"지점"] = "홍도"
df.loc[df["지점"]==22194,"지점"] = "홍도"

df1.loc[df1["지점"]==22297,"지점"] = "가거도"
df1.loc[df1["지점"]==22193,"지점"] = "가거도"
df1.loc[df1["지점"]==22103,"지점"] = "거문도"
df1.loc[df1["지점"]==22104,"지점"] = "거제도"
df1.loc[df1["지점"]==22300,"지점"] = "남해239"
df1.loc[df1["지점"]==22301,"지점"] = "남해465"
df1.loc[df1["지점"]==22101,"지점"] = "덕적도"
df1.loc[df1["지점"]==22105,"지점"] = "동해 "
df1.loc[df1["지점"]==22302,"지점"] = "동해78 "
df1.loc[df1["지점"]==22107,"지점"] = "마라도 "
df1.loc[df1["지점"]==22186,"지점"] = "부안 "
df1.loc[df1["지점"]==22187,"지점"] = "서귀포"
df1.loc[df1["지점"]==22191,"지점"] = "서해170"
df1.loc[df1["지점"]==22299,"지점"] = "서해190"
df1.loc[df1["지점"]==22192,"지점"] = "서해206"
df1.loc[df1["지점"]==22183,"지점"] = "신안"
df1.loc[df1["지점"]==22108,"지점"] = "외연도"
df1.loc[df1["지점"]==21229,"지점"] = "울릉도"
df1.loc[df1["지점"]==22189,"지점"] = "울산"
df1.loc[df1["지점"]==22190,"지점"] = "울진"
df1.loc[df1["지점"]==22185,"지점"] = "인천"
df1.loc[df1["지점"]==22184,"지점"] = "추자도"
df1.loc[df1["지점"]==22102,"지점"] = "칠발도"
df1.loc[df1["지점"]==22188,"지점"] = "통영"
df1.loc[df1["지점"]==22106,"지점"] = "포항"
df1.loc[df1["지점"]==22303,"지점"] = "풍도"
df1.loc[df1["지점"]==22298,"지점"] = "홍도"
df1.loc[df1["지점"]==22194,"지점"] = "홍도"

# %%
#지점 데이터 변경 확인
df
# Out:
#            지점                일시  풍속(m/s)  풍향(deg)  GUST풍속(m/s)  현지기압(hPa)  \
# 0         울릉도   2020-01-01 0:00      6.6    273.0         10.5     1026.4
# 1         울릉도   2020-01-01 2:00      7.5    275.0         10.6     1025.5
# 2         울릉도   2020-01-01 3:00      7.5    284.0         10.6     1025.5
# 3         울릉도   2020-01-01 4:00      4.9    315.0          7.4     1025.2
# 4         울릉도   2020-01-01 5:00      5.8    297.0          8.7     1024.7
# ...       ...               ...      ...      ...          ...        ...
# 380692  동해78   2021-12-31 19:00     10.9    336.0         15.1     1024.9
# 380693  동해78   2021-12-31 20:00      8.9    334.0         12.2     1025.5
# 380694  동해78   2021-12-31 21:00      8.8    320.0         14.1     1025.7
# 380695  동해78   2021-12-31 22:00      8.2    315.0         10.7     1026.2
# 380696  동해78   2021-12-31 23:00      8.0    307.0         10.8     1026.2
#
#         습도(%)  기온(°C)  수온(°C)  최대파고(m)  유의파고(m)  평균파고(m)  파주기(sec)  파향(deg)
# ...

# %%
df1
# Out:
#          지점                일시  풍속(m/s)  풍향(deg)  GUST풍속(m/s)  현지기압(hPa)  \
# 0       울릉도   2011-12-28 0:00      2.1    304.0          4.2     1031.0
# 1       울릉도   2011-12-28 1:00      4.5    293.0          6.9     1030.6
# 2       울릉도   2011-12-28 2:00      4.6    277.0          7.2     1030.4
# 3       울릉도   2011-12-28 3:00      3.2    285.0          6.0     1030.4
# 4       울릉도   2011-12-28 4:00      2.7    276.0          4.6     1030.5
# ...     ...               ...      ...      ...          ...        ...
# 984459   홍도  2019-12-31 19:00      8.0    352.0         12.5     1034.9
# 984460   홍도  2019-12-31 20:00      7.3    349.0         11.8     1034.8
# 984461   홍도  2019-12-31 21:00      6.4    345.0         10.0     1034.7
# 984462   홍도  2019-12-31 22:00      7.6      3.0         13.6     1034.0
# 984463   홍도  2019-12-31 23:00      5.5      1.0         10.4     1034.1
#
#         습도(%)  기온(°C)  수온(°C)  최대파고(m)  유의파고(m)  평균파고(m)  파주기(sec)  파향(deg)
# ...

# %%
#현재 null값이 어떤 열들에 존재하는지 확인=>모든 열에 존재
empty_cols = df.columns[df.isna().any()].tolist()
print("빈 값이 있는 열:", empty_cols)
empty_cols = df.columns[df1.isna().any()].tolist()
print("빈 값이 있는 열:", empty_cols)
# Out:
# 빈 값이 있는 열: ['지점', '일시', '풍속(m/s)', '풍향(deg)', 'GUST풍속(m/s)', '현지기압(hPa)', '습도(%)', '기온(°C)', '수온(°C)', '최대파고(m)', '유의파고(m)', '평균파고(m)', '파주기(sec)', '파향(deg)']
# 빈 값이 있는 열: ['지점', '일시', '풍속(m/s)', '풍향(deg)', 'GUST풍속(m/s)', '현지기압(hPa)', '습도(%)', '기온(°C)', '수온(°C)', '최대파고(m)', '유의파고(m)', '평균파고(m)', '파주기(sec)', '파향(deg)']

# %%
#특성별로 몇개의 결측치를 갖고있는지 확인=>5%가 안되는 정도
empty_rows = df.isna().sum()
print("빈 값이 존재하는 행의 개수:\n", empty_rows)
empty_rows1 = df1.isna().sum()
print("빈 값이 존재하는 행의 개수:\n", empty_rows1)
# Out:
# 빈 값이 존재하는 행의 개수:
#  지점                 1
# 일시                 1
# 풍속(m/s)         5632
# 풍향(deg)         7385
# GUST풍속(m/s)     6164
# 현지기압(hPa)       3060
# 습도(%)          12764
# 기온(°C)          7008
# 수온(°C)          3437
# 최대파고(m)         1843
# 유의파고(m)         2398
# 평균파고(m)         5727
# 파주기(sec)        4077
# 파향(deg)          390
# dtype: int64
# 빈 값이 존재하는 행의 개수:
#  지점                 8
# 일시                 8
# 풍속(m/s)        18043
# 풍향(deg)        21902
# GUST풍속(m/s)    19080
# 현지기압(hPa)      21124
# 습도(%)          20046
# 기온(°C)         17618
# 수온(°C)         15022
# 최대파고(m)         4166
# 유의파고(m)         6552
# 평균파고(m)        12039
# 파주기(sec)        7588
# 파향(deg)         7070
# dtype: int64

# %%
#결측치를 평균치로 대체
df['풍속(m/s)'] = df['풍속(m/s)'].interpolate(method='polynomial', order=1)
df['풍향(deg)'] = df['풍향(deg)'].interpolate(method='polynomial', order=1)
df['GUST풍속(m/s)'] = df['GUST풍속(m/s)'].interpolate(method='polynomial', order=1)
df['현지기압(hPa)'] = df['현지기압(hPa)'].interpolate(method='polynomial', order=1)
df['습도(%)'] = df['습도(%)'].interpolate(method='polynomial', order=1)
df['기온(°C)'] = df['기온(°C)'].interpolate(method='polynomial', order=1)
df['수온(°C)'] = df['수온(°C)'].interpolate(method='polynomial', order=1)
df['최대파고(m)'] = df['최대파고(m)'].interpolate(method='polynomial', order=1)
df['유의파고(m)'] = df['유의파고(m)'].interpolate(method='polynomial', order=1)
df['평균파고(m)'] = df['평균파고(m)'].interpolate(method='polynomial', order=1)
df['파주기(sec)'] = df['파주기(sec)'].interpolate(method='polynomial', order=1)
df['파향(deg)'] = df['파향(deg)'].interpolate(method='polynomial', order=1)

df1['풍속(m/s)'] = df1['풍속(m/s)'].interpolate(method='polynomial', order=1)
df1['풍향(deg)'] = df1['풍향(deg)'].interpolate(method='polynomial', order=1)
df1['GUST풍속(m/s)'] = df1['GUST풍속(m/s)'].interpolate(method='polynomial', order=1)
df1['현지기압(hPa)'] = df1['현지기압(hPa)'].interpolate(method='polynomial', order=1)
df1['습도(%)'] = df1['습도(%)'].interpolate(method='polynomial', order=1)
df1['기온(°C)'] = df1['기온(°C)'].interpolate(method='polynomial', order=1)
df1['수온(°C)'] = df1['수온(°C)'].interpolate(method='polynomial', order=1)
df1['최대파고(m)'] = df1['최대파고(m)'].interpolate(method='polynomial', order=1)
df1['유의파고(m)'] = df1['유의파고(m)'].interpolate(method='polynomial', order=1)
df1['평균파고(m)'] = df1['평균파고(m)'].interpolate(method='polynomial', order=1)
df1['파주기(sec)'] = df1['파주기(sec)'].interpolate(method='polynomial', order=1)
df1['파향(deg)'] = df1['파향(deg)'].interpolate(method='polynomial', order=1)

# %%
#결측치 남아있는지 확인 => 행과 행 사이의 빈칸임을 확인 => 그냥 삭제 필요
empty_rows = df.isna().sum()
print("빈 값이 존재하는 행의 개수:\n", empty_rows)
empty_rows = df1.isna().sum()
print("빈 값이 존재하는 행의 개수:\n", empty_rows)
# Out:
# 빈 값이 존재하는 행의 개수:
#  지점             1
# 일시             1
# 풍속(m/s)        0
# 풍향(deg)        0
# GUST풍속(m/s)    0
# 현지기압(hPa)      0
# 습도(%)          0
# 기온(°C)         0
# 수온(°C)         0
# 최대파고(m)        0
# 유의파고(m)        0
# 평균파고(m)        0
# 파주기(sec)       0
# 파향(deg)        0
# dtype: int64
# 빈 값이 존재하는 행의 개수:
#  지점             8
# 일시             8
# 풍속(m/s)        0
# 풍향(deg)        0
# GUST풍속(m/s)    0
# 현지기압(hPa)      0
# 습도(%)          0
# 기온(°C)         0
# 수온(°C)         0
# 최대파고(m)        0
# 유의파고(m)        0
# 평균파고(m)        0
# 파주기(sec)       0
# 파향(deg)        0
# dtype: int64

# %%
#빈칸 제거
df = df.dropna()

# %%
#다시 결측치 확인=>ok
empty_rows = df.isna().sum()
print("빈 값이 존재하는 행의 개수:\n", empty_rows)
# Out:
# 빈 값이 존재하는 행의 개수:
#  지점             0
# 일시             0
# 풍속(m/s)        0
# 풍향(deg)        0
# GUST풍속(m/s)    0
# 현지기압(hPa)      0
# 습도(%)          0
# 기온(°C)         0
# 수온(°C)         0
# 최대파고(m)        0
# 유의파고(m)        0
# 평균파고(m)        0
# 파주기(sec)       0
# 파향(deg)        0
# dtype: int64

# %%
#해당 데이터 다시 저장
df.to_csv("/Users/82107/Downloads/OBS_BUOY_TIM_2020_2021_modified1.csv", index=False)
df.to_csv("/Users/82107/Downloads/OBS_BUOY_TIM_2011_2019_modified1.csv", index=False)
